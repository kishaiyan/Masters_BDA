# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
education=pd.read_csv("./education.csv")
gambling=pd.read_csv("./gambling.csv")
health=pd.read_csv("./health.csv")
income=pd.read_csv("./income.csv")
lone=pd.read_csv("./lone.csv")
welfare=pd.read_csv("./welfare.csv")
employment=pd.read_csv("./Employment data.csv")
Expenditure=pd.read_csv("./Mental Health Expenditure.csv",)
social_media=pd.read_csv("./social_media_usage.csv")
state=pd.read_csv("./State health.csv")

# %%
education.info()
gambling.info()
health.info()
income.info()
lone.info()
welfare.info()
employment.info()
Expenditure.info()
social_media.info()
state.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Year     10 non-null     int64
#  1   Persons  10 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 288.0 bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      13 non-null     int64
#  1   gambling  13 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 336.0 bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4153 entries, 0 to 4152
# Data columns (total 34 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   IndicatorCode               4153 non-null   object
#  1   Indicator                   4153 non-null   object
# ...

# %%
education.head()
# Out:
#    Year  Persons
# 0  2014     59.9
# 1  2015     62.1
# 2  2016     63.1
# 3  2017     64.2
# 4  2018     65.1

# %%
# @title Year vs Persons

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Year']
  ys = series['Persons']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = education.sort_values('Year', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Year')
_ = plt.ylabel('Persons')

# %%
gambling[4:]
# Out:
#     Year  gambling
# 4   2014      23.5
# 5   2015      24.8
# 6   2016      25.4
# 7   2017      24.9
# 8   2018      25.8
# 9   2019      25.9
# 10  2020      21.2
# 11  2021      23.2
# 12  2022      24.1

# %%
# @title Year vs gambling

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Year']
  ys = series['gambling']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = gambling.sort_values('Year', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Year')
_ = plt.ylabel('gambling')

# %%
combined1=pd.merge(education,gambling,on='Year',how='outer')

# %%
employment[1:]
# Out:
#     Year unemployed  employed
# 1   2014     89,500    199900
# 2   2015     94,500    196800
# 3   2016      93700    200600
# 4   2017      83200    214200
# 5   2018      74300    197000
# 6   2019      77300    194800
# 7   2020     113800    190000
# 8   2021      78800    177400
# 9   2022      64500    150000
# 10  2023      68700    145600

# %%
combined2=pd.merge(combined1,employment,on='Year',how='outer')

# %%
health.head()
# Out:
#          IndicatorCode                                          Indicator  \
# 0  GHED_CHEGDP_SHA2011  Current health expenditure (CHE) as percentage...
# 1  GHED_CHEGDP_SHA2011  Current health expenditure (CHE) as percentage...
# 2  GHED_CHEGDP_SHA2011  Current health expenditure (CHE) as percentage...
# 3  GHED_CHEGDP_SHA2011  Current health expenditure (CHE) as percentage...
# 4  GHED_CHEGDP_SHA2011  Current health expenditure (CHE) as percentage...
#
#   ValueType ParentLocationCode         ParentLocation Location type  \
# 0   numeric                EUR                 Europe       Country
# 1   numeric               SEAR        South-East Asia       Country
# 2   numeric                WPR        Western Pacific       Country
# 3   numeric                EMR  Eastern Mediterranean       Country
# 4   numeric                AFR                 Africa       Country
#
#   SpatialDimValueCode     Location Period type  Period  ...  FactValueUoM  \
# ...

# %%
health.columns.tolist()
# Out:
# ['IndicatorCode',
#  'Indicator',
#  'ValueType',
#  'ParentLocationCode',
#  'ParentLocation',
#  'Location type',
#  'SpatialDimValueCode',
#  'Location',
#  'Period type',
#  'Period',
#  'IsLatestYear',
#  'Dim1 type',
#  'Dim1',
#  'Dim1ValueCode',
#  'Dim2 type',
#  'Dim2',
#  'Dim2ValueCode',
#  'Dim3 type',
#  'Dim3',
#  'Dim3ValueCode',
#  'DataSourceDimValueCode',
#  'DataSource',
#  'FactValueNumericPrefix',
#  'FactValueNumeric',
#  'FactValueUoM',
#  'FactValueNumericLowPrefix',
#  'FactValueNumericLow',
#  'FactValueNumericHighPrefix',
#  'FactValueNumericHigh',
#  'Value',
#  'FactValueTranslationID',
#  'FactComments',
#  'Language',
#  'DateModified']

# %%
healthcolumnstodrop=['IndicatorCode',
 'Indicator',
 'ValueType',
 'ParentLocationCode',
 'ParentLocation',
 'Location type',
 'SpatialDimValueCode',
 'Period type',
 'IsLatestYear',
 'Dim1 type',
 'Dim1',
 'Dim1ValueCode',
 'Dim2 type',
 'Dim2',
 'Dim2ValueCode',
 'Dim3 type',
 'Dim3',
 'Dim3ValueCode',
 'DataSourceDimValueCode',
 'DataSource',
 'FactValueNumericPrefix',
 'FactValueNumeric',
 'FactValueUoM',
 'FactValueNumericLowPrefix',
 'FactValueNumericLow',
 'FactValueNumericHighPrefix',
 'FactValueNumericHigh',
 'FactValueTranslationID',
 'FactComments',
 'Language',
 'DateModified']

# %%
health.drop(healthcolumnstodrop,axis=1,inplace=True)

# %%
health=health[health['Location']=='Australia']

# %%
health
# Out:
#        Location  Period  Value
# 6     Australia    2021  10.54
# 195   Australia    2020  10.68
# 381   Australia    2019  10.22
# 570   Australia    2018  10.06
# 759   Australia    2017  10.12
# 946   Australia    2016  10.09
# 1138  Australia    2015  10.18
# 1508  Australia    2014   9.83
# 1683  Australia    2013   8.75
# 1868  Australia    2012   8.67
# 2058  Australia    2011   8.54
# 2247  Australia    2010   8.42
# 2435  Australia    2009   8.54
# 2623  Australia    2008   8.25
# 2811  Australia    2007   8.05
# 2998  Australia    2006   7.98
# 3185  Australia    2005   7.97
# 3380  Australia    2004   8.09
# 3564  Australia    2003   7.88
# 3755  Australia    2002   7.88
# 3940  Australia    2001   7.68
# 4125  Australia    2000   7.59

# %%
# health=health[health['Period']>=2014]

# %%
health.drop('Location',axis=1,inplace=True)
health
# Out:
#       Period  Value
# 6       2021  10.54
# 195     2020  10.68
# 381     2019  10.22
# 570     2018  10.06
# 759     2017  10.12
# 946     2016  10.09
# 1138    2015  10.18
# 1508    2014   9.83
# 1683    2013   8.75
# 1868    2012   8.67
# 2058    2011   8.54
# 2247    2010   8.42
# 2435    2009   8.54
# 2623    2008   8.25
# 2811    2007   8.05
# 2998    2006   7.98
# 3185    2005   7.97
# 3380    2004   8.09
# 3564    2003   7.88
# 3755    2002   7.88
# 3940    2001   7.68
# 4125    2000   7.59

# %%
health.rename(columns={'Period':'Year'},inplace=True)

# %%
health.reset_index(drop=True,inplace=True)

# %%
combined3=pd.merge(combined2,health,on='Year',how='outer')

# %%
income
# Out:
#    Year  below 40%  40-50  below 50%
# 0  2009        4.3    6.5       10.8
# 1  2011        4.4    7.1       11.5
# 2  2013        5.9    7.7       13.6
# 3  2015        5.1    7.1       12.2
# 4  2017        5.5    6.5       12.0
# 5  2019        5.5    5.0       10.5
# 6  2021        5.1    4.2        9.3
# 7  2023        5.6    4.9       10.5

# %%
combined4=pd.merge(combined3,income,on='Year',how='outer')

# %%
lone
# Out:
#     Year  Total Isolation  loneliness
# 0   2010               11          14
# 1   2011               12          15
# 2   2012               11          14
# 3   2013               12          15
# 4   2014               12          15
# 5   2015               12          15
# 6   2016               12          14
# 7   2017               14          15
# 8   2018               13          15
# 9   2019               13          16
# 10  2020               15          15
# 11  2021               16          17
# 12  2022               15          16

# %%
combined5=pd.merge(combined4,lone,on='Year',how='outer')

# %%
social_media
# Out:
#    Year  Population
# 0  2014        52.0
# 1  2015        58.0
# 2  2016        62.0
# 3  2017        65.0
# 4  2018        69.0
# 5  2019        72.0
# 6  2020        71.0
# 7  2021        79.9
# 8  2022        82.7

# %%
combined6=pd.merge(combined5,social_media,on='Year',how='outer')

# %%
welfare
# Out:
#     Year  welfare per capita expense  government expense
# 0   2010                        6515                 142
# 1   2011                        6689                 148
# 2   2012                        7030                 158
# 3   2013                        7068                 162
# 4   2014                        7066                 165
# 5   2015                        7432                 176
# 6   2016                        7429                 178
# 7   2017                        7216                 176
# 8   2018                        7348                 182
# 9   2019                        7334                 184
# 10  2020                        8146                 208
# 11  2021                        9010                 231
# 12  2022                        8245                 212

# %%
combined7=pd.merge(combined6,welfare,on='Year',how='outer')

# %%
pivot_state = state.pivot_table(index='Year', columns='Expenditure', values='Data for table').reset_index()

# %%
pivot_state['total']=pivot_state.iloc[:, 1:].sum(axis=1)

# %%
pivot_state.columns.tolist()
# Out:
# ['Year',
#  'Community mental health care services',
#  'Grants to non-government organisations',
#  'Other indirect expenditure',
#  'Public psychiatric hospitals',
#  'Residential mental health services',
#  'Specialised psychiatric units or wards in public acute hospitals',
#  'total']

# %%
pivotcolumnstodrop=[
 'Community mental health care services',
 'Grants to non-government organisations',
 'Other indirect expenditure',
 'Public psychiatric hospitals',
 'Residential mental health services',
 'Specialised psychiatric units or wards in public acute hospitals'
 ]

# %%
pivot_state.drop(pivotcolumnstodrop,axis=1,inplace=True)

# %%
pivot_state['total']=pivot_state['total']/1000

# %%
pivot_state
# Out:
# Expenditure  Year      total
# 0            2010  5279530.0
# 1            2011  5562878.0
# 2            2012  5721190.0
# 3            2013  5728154.0
# 4            2014  5925457.0
# 5            2015  6087784.0
# 6            2016  6238121.0
# 7            2017  6399952.0
# 8            2018  6637391.0
# 9            2019  6893350.0
# 10           2020  6915234.0
# 11           2021  7171557.0
# 12           2022  7373415.0

# %%
finaldf=pd.merge(combined7,pivot_state,on='Year',how='outer')

# %%
finaldf.shape
# Out:
# (24, 15)

# %%
finaldf=finaldf[finaldf['Year']>=2010]

# %%
finaldf.sort_values('Year',ascending=True,inplace=True)

# %%
finaldf
# Out:
#     Year  Persons  gambling unemployed  employed  Value  below 40%  40-50  \
# 10  2010      NaN      22.5        NaN       NaN   8.42        NaN    NaN
# 11  2011      NaN      23.0        NaN       NaN   8.54        4.4    7.1
# 12  2012      NaN      23.8        NaN       NaN   8.67        NaN    NaN
# 13  2013      NaN      23.5     92,700  203400.0   8.75        5.9    7.7
# 0   2014     59.9      23.5     89,500  199900.0   9.83        NaN    NaN
# 1   2015     62.1      24.8     94,500  196800.0  10.18        5.1    7.1
# 2   2016     63.1      25.4      93700  200600.0  10.09        NaN    NaN
# 3   2017     64.2      24.9      83200  214200.0  10.12        5.5    6.5
# 4   2018     65.1      25.8      74300  197000.0  10.06        NaN    NaN
# 5   2019     65.1      25.9      77300  194800.0  10.22        5.5    5.0
# 6   2020     66.6      21.2     113800  190000.0  10.68        NaN    NaN
# 7   2021     68.3      23.2      78800  177400.0  10.54        5.1    4.2
# ...

# %%
finaldf['unemployed']=pd.to_numeric(finaldf['unemployed'],errors='coerce')

# %%
target=pd.read_csv("./Mental Health Expenditure.csv")

# %%
target.loc[target['Year'].isin([2010, 2011]), 'mental health commission'] = 0

# %%
targetcolumnstodrop=['Unnamed: 8',
 'Unnamed: 9',
 'Unnamed: 10']

# %%
target.drop(targetcolumnstodrop,axis=1,inplace=True)

# %%
target=target[:13]

# %%
target['total']=target.iloc[:, 1:].sum(axis=1)

# %%
target['total']=target['total']/1000

# %%
columndrop=['medicare',
 'federal government expense',
 'mental health commission',
 'nation program',
 'Pharma',
 'private Health insurance',
 'research']

# %%
final=pd.merge(finaldf,target,on='Year',how='outer')

# %%
final['finaltotal']=final['total_x']+final['total_y']

# %%
finalcolumndrop=['total_x','total_y']

# %%
final.drop(finalcolumndrop,axis=1,inplace=True)

# %%
corr=final.corr()

plt.figure(figsize=(20,20))
sns.heatmap(corr,annot=True)
plt.title("Correlation Matrix of few selected Features")
plt.show()

# %%
final=final[final['Year']<=2022]

# %%
from sklearn.model_selection import train_test_split
target=final['finaltotal']
features=final.drop('finaltotal',axis=1)
X_train,X_test,y_train,y_test=train_test_split(features,target,test_size=0.3,random_state=42)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.impute import SimpleImputer

# Corrected pipeline definition
pre_proc = Pipeline([
    ('impute', SimpleImputer(strategy='mean')),
    ('scale', StandardScaler()),
])

# You can also create a complete pipeline with a model
lg_pipeline = Pipeline([
    ('pre_proc', pre_proc),
    ('regressor', LinearRegression())
])

# Print the pipeline steps to verify
print(lg_pipeline)
# Out:
# Pipeline(steps=[('pre_proc',
#                  Pipeline(steps=[('impute', SimpleImputer()),
#                                  ('scale', StandardScaler())])),
#                 ('regressor', LinearRegression())])

# %%
y_test
# Out:
# 11    11319256.0
# 9     10803265.0
# 0      8047289.0
# 8     10322002.0
# Name: finaltotal, dtype: float64

# %%
lg_pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('pre_proc',
#                  Pipeline(steps=[('impute', SimpleImputer()),
#                                  ('scale', StandardScaler())])),
#                 ('regressor', LinearRegression())])

# %%
from sklearn.metrics import mean_squared_error,r2_score

y_pred=lg_pipeline.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R² Score: {r2}")
# Out:
# Mean Squared Error: 254011046632.92392
# R² Score: 0.8372237126325058

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score

X_train, X_test, y_train, y_test = train_test_split(features,target, test_size=0.3, random_state=42)

# Print shapes for debugging
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)

# Preprocessing pipeline
pre_proc = Pipeline([
    ('impute', SimpleImputer(strategy='mean')),
    ('scale', StandardScaler())
])

# Define models and their hyperparameters for tuning
models_and_params = {
    'Linear Regression': (LinearRegression(), {}),
    'Ridge': (Ridge(), {'regressor__alpha': [0.1, 1.0, 10.0]}),
    'Lasso': (Lasso(), {'regressor__alpha': [0.1, 1.0, 10.0]}),
    'ElasticNet': (ElasticNet(), {'regressor__alpha': [0.1, 1.0, 10.0], 'regressor__l1_ratio': [0.2, 0.5, 0.8]}),
    'Decision Tree': (DecisionTreeRegressor(), {'regressor__max_depth': [3, 5, 7]}),
    'Random Forest': (RandomForestRegressor(), {'regressor__n_estimators': [50, 100, 200], 'regressor__max_depth': [3, 5, 7]}),
    'Gradient Boosting': (GradientBoostingRegressor(), {'regressor__n_estimators': [50, 100, 200], 'regressor__learning_rate': [0.01, 0.1, 0.2]}),
    'Support Vector Machine': (SVR(), {'regressor__C': [0.1, 1.0, 10.0], 'regressor__gamma': ['scale', 'auto']})
}

# Dictionary to store results and best models
results = {}
best_models = {}

# Iterate through models, create pipelines, tune hyperparameters, fit, predict, and evaluate
for name, (model, params) in models_and_params.items():
    pipeline = Pipeline([
        ('pre_proc', pre_proc),
        ('regressor', model)
    ])

    grid_search = GridSearchCV(pipeline, param_grid=params, cv=2, scoring='r2')
    grid_search.fit(X_train, y_train)

    best_params = grid_search.best_params_
    best_model = grid_search.best_estimator_

    # Store best model
    best_models[name] = best_model

    # Evaluate on the test set
    y_pred = best_model.predict(X_test)

    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    results[name] = {'Best Params': best_params, 'MSE': mse, 'R2': r2}

# Display results
for name, metrics in results.items():
    print(f"--- {name} ---")
    print(f"Best Params: {metrics['Best Params']}")
    # print(f"Mean Squared Error: {metrics['MSE']}")
    print(f"R² Score: {metrics['R2']}")
    print()
# Out:
# X_train shape: (9, 14)
# X_test shape: (4, 14)
# y_train shape: (9,)
# y_test shape: (4,)
# --- Linear Regression ---
# Best Params: {}
# R² Score: 0.8372237126325058
#
# --- Ridge ---
# Best Params: {'regressor__alpha': 1.0}
# R² Score: 0.8652259339273544
#
# --- Lasso ---
# Best Params: {'regressor__alpha': 0.1}
# R² Score: 0.9772333337206606
#
# --- ElasticNet ---
# Best Params: {'regressor__alpha': 1.0, 'regressor__l1_ratio': 0.8}
# R² Score: 0.858620298184438
#
# --- Decision Tree ---
# Best Params: {'regressor__max_depth': 5}
# R² Score: 0.6737717345397689
#
# --- Random Forest ---
# Best Params: {'regressor__max_depth': 5, 'regressor__n_estimators': 50}
# R² Score: 0.7520362071855063
#
# --- Gradient Boosting ---
# Best Params: {'regressor__learning_rate': 0.1, 'regressor__n_estimators': 100}
# R² Score: 0.7611113939720069
#
# --- Support Vector Machine ---
# Best Params: {'regressor__C': 10.0, 'regressor__gamma': 'auto'}
# R² Score: -0.1242103955197067

# %%
lasso_model=best_models['Lasso']

# %%
lasso_model.fit(X_train,y_train)
final_pred=lasso_model.predict(X_test)
print("R2 metric for the final model is ",r2_score(y_test,final_pred))
# Out:
# R2 metric for the final model is  0.9772333337206606

# %%
import matplotlib.pyplot as plt

# Generate predictions using the best model
y_pred = lasso_model.predict(X_test)

# Create a DataFrame for easier plotting
results_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})

# Plot
plt.figure(figsize=(10, 6))
plt.scatter(results_df['Actual'], results_df['Predicted'], color='blue', label='Predicted vs Actual')
plt.plot([results_df['Actual'].min(), results_df['Actual'].max()],
         [results_df['Actual'].min(), results_df['Actual'].max()],
         color='red', linestyle='--', label='Perfect Prediction')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted Values')
plt.legend()
plt.grid(True)
plt.show()
